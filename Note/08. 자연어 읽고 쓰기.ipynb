# %% [markdown]
# # 08. 자연어 읽고 쓰기

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import string
import operator


def cleanInput(input):
    input = re.sub('\n+', " ", input).lower()
    input = re.sub('\[[0-9]*\]', "", input)
    input = re.sub(' +', " ", input)
    input = bytes(input, "UTF-8")
    input = input.decode("ascii", "ignore")
    cleanInput = []
    input = input.split(' ')
    for item in input:
        item = item.strip(string.punctuation)
        if len(item) > 1 or (item.lower() == 'a' or item.lower() == 'i'):
            cleanInput.append(item)
    return cleanInput

def getNgrams(input, n):
    input = cleanInput(input)
    output = {}
    for i in range(len(input)-n+1):
        ngramTemp = " ".join(input[i:i+n])
        if ngramTemp not in output:
            output[ngramTemp] = 0
        output[ngramTemp] += 1
    return output

content = str(urlopen("http://pythonscraping.com/files/inaugurationSpeech.txt").read(),'utf-8')
ngrams = getNgrams(content, 2)
sortedNGrams = sorted(ngrams.items(), key = operator.itemgetter(1), reverse=True)
print(sortedNGrams)
# Out:
# [('of the', 213), ('in the', 65), ('to the', 61), ('by the', 41), ('the constitution', 34), ('of our', 29), ('to be', 26), ('the people', 24), ('from the', 24), ('and the', 23), ('that the', 23), ('it is', 23), ('of a', 22), ('the executive', 19), ('of their', 19), ('may be', 19), ('of that', 18), ('of power', 16), ('have been', 16), ('of its', 16), ('is the', 16), ('for the', 16), ('the government', 15), ('all the', 15), ('with the', 15), ('has been', 13), ('there is', 13), ('which they', 13), ('power to', 12), ('the power', 11), ('their own', 11), ('as to', 11), ('spirit of', 11), ('that of', 11), ('the same', 11), ('the united', 10), ('the character', 10), ('as the', 10), ('can be', 10), ('of liberty', 10), ('of all', 10), ('upon the', 10), ('but the', 10), ('which it', 10), ('which the', 10), ('united states', 10), ('part of', 10), ('of any', 9), ('the president', 9), ('the whole', 9), ('it was', 9), ('to a', 9), ('of my', 9), ('the great', 9), ('on the', 9), ('by a', 8), ('and that', 8), ('character of', 8), ('of those', 8), ('the states', 8), ('would be', 8), ('it may', 8), ('in their', 8), ('which our', 8), ('the legislative', 8), ('should be', 8), ('and of', 8), ('the public', 8), ('acts of', 7), ('at the', 7), ('to their', 7), ('as well', 7), ('citizens of', 7), ('the general', 7), ('the powers', 7), ('any other', 7), ('to have', 7), ('upon their', 6), ('government and', 6), ('relation to', 6), ('the influence', 6), ('them to', 6), ('state of', 6), ('and in', 6), ('under the', 6), ('our system', 6), ('one of', 6), ('of one', 6), ('in its', 6), ('those of', 6), ('it would', 6), ('is a', 6), ('to that', 6), ('to me', 6), ('that they', 6), ('the most', 6), ('the state', 6), ('some of', 6), ('the spirit', 6), ('of this', 6), ('the latter', 5), ('it has', 5), ('as a', 5), ('the acts', 5), ('to them', 5), ('by any', 5), ('in relation', 5), ('in my', 5), ('is in', 5), ('to our', 5), ('not only', 5), ('i shall', 5), ('as it', 5), ('well as', 5), ('for which', 5), ('by which', 5), ('that instrument', 5), ('of no', 5), ('be found', 5), ('might be', 5), ('the citizen', 5), ('the veto', 5), ('people to', 5), ('shall be', 5), ('he is', 5), ('the judiciary', 5), ('in our', 5), ('the country', 5), ('far as', 5), ('was the', 5), ('of each', 5), ('i have', 5), ('the former', 5), ('which has', 5), ('the other', 5), ('not to', 5), ('to his', 5), ('power which', 5), ('our country', 5), ('the legislature', 5), ('of these', 5), ('of them', 5), ('the citizens', 5), ('to which', 5), ('exercise of', 5), ('or the', 5), ('which may', 4), ('may have', 4), ('continuance of', 4), ('must be', 4), ('of such', 4), ('of government', 4), ('does not', 4), ('they have', 4), ('powers which', 4), ('that a', 4), ('the union', 4), ('in his', 4), ('difficulty in', 4), ('control of', 4), ('power of', 4), ('to its', 4), ('the hands', 4), ('if this', 4), ('the treasury', 4), ('examination of', 4), ('control the', 4), ('with which', 4), ('of every', 4), ('be the', 4), ('hands of', 4), ('been the', 4), ('executive department', 4), ('been granted', 4), ('this is', 4), ('interests of', 4), ('between the', 4), ('that which', 4), ('to my', 4), ('duty of', 4), ('be used', 4), ('intended to', 4), ('country in', 4), ('danger to', 4), ('in a', 4), ('the contrary', 4), ('had been', 4), ('to make', 4), ('citizen of', 4), ('any of', 4), ('the convention', 4), ('if there', 4), ('members of', 4), ('at least', 4), ('of an', 4), ('it to', 4), ('was to', 4), ('me to', 4), ('the senate', 4), ('influence of', 4), ('necessary to', 4), ('people of', 4), ('to produce', 4), ('general government', 4), ('such a', 4), ('given to', 4), ('the majority', 4), ('a spirit', 4), ('departments of', 4), ('that i', 4), ('government but', 4), ('and i', 4), ('it will', 4), ('our government', 4), ('than the', 4), ('not the', 4), ('to all', 4), ('mode of', 4), ('possessed by', 4), ('of his', 4), ('assigned to', 4), ('by their', 4), ('the principles', 4), ('it appears', 4), ('but that', 4), ('of congres ...

# %%
def isCommon(ngram):
    commonWords = ["the", "be", "and", "of", "a", "in", "to", "have", "it", "i", "that", "for", "you", "he", "with", "on", "do", "say", "this", "they", "is", "an", "at", "but","we", "his", "from", "that", "not", "by", "she", "or", "as", "what", "go", "their","can", "who", "get", "if", "would", "her", "all", "my", "make", "about", "know", "will","as", "up", "one", "time", "has", "been", "there", "year", "so", "think", "when", "which", "them", "some", "me", "people", "take", "out", "into", "just", "see", "him", "your", "come", "could", "now", "than", "like", "other", "how", "then", "its", "our", "two", "more", "these", "want", "way", "look", "first", "also", "new", "because", "day", "more", "use", "no", "man", "find", "here", "thing", "give", "many", "well"]
    for word in ngram:
        if word in commonWords:
            return True
    return False

# %%
def cleanText(input):
    input = re.sub('\n+', " ", input).lower()
    input = re.sub('\[[0-9]*\]', "", input)
    input = re.sub(' +', " ", input)
    input = re.sub("u\.s\.", "us", input)
    input = bytes(input, "UTF-8")
    input = input.decode("ascii", "ignore")
    return input

def cleanInput(input):
    input = cleanText(input)
    cleanInput = []
    input = input.split(' ')
    for item in input:
        item = item.strip(string.punctuation)
        if len(item) > 1 or (item.lower() == 'a' or item.lower() == 'i'):
            cleanInput.append(item)
    return cleanInput

def getNgrams(input, n):
    input = cleanInput(input)
    output = {}
    for i in range(len(input)-n+1):
        ngramTemp = " ".join(input[i:i+n])
        if ngramTemp not in output:
            output[ngramTemp] = 0
        output[ngramTemp] += 1
    return output

def getFirstSentenceContaining(ngram, content):
    #print(ngram)
    sentences = content.split(".")
    for sentence in sentences: 
        if ngram in sentence:
            return sentence
    return ""

content = str(urlopen("http://pythonscraping.com/files/space.txt").read(), 'utf-8')
ngrams = getNgrams(content, 2)
sortedNGrams = sorted(ngrams.items(), key = operator.itemgetter(1), reverse = True)
print(sortedNGrams)
# Out:
# [('in space', 44), ('the station', 42), ('on the', 36), ('of the', 34), ('the astronauts', 24), ('space station', 23), ('of a', 22), ('the space', 22), ('in the', 17), ('to the', 14), ('to be', 13), ('mission control', 13), ('station is', 13), ('is a', 12), ('from the', 12), ('for the', 12), ('have to', 11), ('and the', 10), ('in a', 10), ('at the', 10), ('and a', 9), ('the ground', 9), ('all the', 9), ('nasa has', 9), ('in orbit', 9), ('with the', 9), ('has a', 9), ('on earth', 9), ('with a', 9), ('on a', 9), ('the stations', 8), ('an astronaut', 8), ('life in', 8), ('for a', 8), ('going to', 8), ('space is', 7), ('a single', 7), ('in zerog', 7), ('into the', 7), ('the astronaut', 7), ('a space', 7), ('have a', 6), ('as a', 6), ('astronauts are', 6), ('about the', 6), ('we have', 6), ('you can', 6), ('would be', 6), ('to run', 6), ('to do', 6), ('the us', 6), ('its a', 6), ('space walk', 6), ('sense of', 6), ('is the', 6), ('how to', 6), ('to mars', 6), ('its own', 5), ('as the', 5), ('of those', 5), ('to fly', 5), ('station and', 5), ('more than', 5), ('the cost', 5), ('to get', 5), ('astronauts who', 5), ('one of', 5), ('and its', 5), ('a year', 5), ('the trash', 5), ('we may', 5), ('it is', 5), ('space the', 5), ('living in', 5), ('part of', 5), ('their own', 5), ('by the', 4), ('the schedule', 4), ('is going', 4), ('on station', 4), ('i go', 4), ('bone mass', 4), ('a sense', 4), ('need to', 4), ('a lot', 4), ('fly in', 4), ('a week', 4), ('become a', 4), ('have been', 4), ('end up', 4), ('there is', 4), ('but the', 4), ('the most', 4), ('the earth', 4), ('could be', 4), ('to live', 4), ('charles says', 4), ('says i', 4), ('space travel', 4), ('at a', 4), ('out of', 4), ('you have', 4), ('at least', 4), ('a long', 4), ('to make', 4), ('spaceflight is', 4), ('station was', 4), ('it just', 4), ('was the', 4), ('had to', 4), ('the workday', 4), ('in houston', 4), ('of it', 4), ('international space', 4), ('i had', 4), ('he says', 4), ('american astronauts', 4), ('the mission', 4), ('each day', 4), ('cost to', 4), ('over the', 4), ('has no', 4), ('or the', 4), ('astronauts have', 4), ('on your', 4), ('houston and', 3), ('is more', 3), ('percent of', 3), ('it has', 3), ('an hour', 3), ('just as', 3), ('the shuttle', 3), ('your arms', 3), ('in their', 3), ('does not', 3), ('working in', 3), ('do it', 3), ('walk is', 3), ('every day', 3), ('a mission', 3), ('hopkins says', 3), ('sleeping bag', 3), ('your body', 3), ('time to', 3), ('as it', 3), ('and while', 3), ('i would', 3), ('things in', 3), ('the work', 3), ('the morning', 3), ('value of', 3), ('up to', 3), ('work in', 3), ('its so', 3), ('and in', 3), ('a vast', 3), ('space shuttles', 3), ('is about', 3), ('this is', 3), ('and you', 3), ('a laptop', 3), ('to become', 3), ('dont know', 3), ('want to', 3), ('the video', 3), ('youre in', 3), ('or more', 3), ('its just', 3), ('we fly', 3), ('nasa the', 3), ('for two', 3), ('the russian', 3), ('the international', 3), ('the first', 3), ('during the', 3), ('ready to', 3), ('it would', 3), ('when you', 3), ('kelly and', 3), ('there are', 3), ('no one', 3), ('it thats', 3), ('all of', 3), ('it was', 3), ('a half', 3), ('to space', 3), ('she says', 3), ('the moon', 3), ('orbit and', 3), ('long time', 3), ('in part', 3), ('i have', 3), ('the real', 3), ('that a', 3), ('across the', 3), ('the body', 3), ('like to', 3), ('ground personnel', 3), ('a time', 3), ('it will', 3), ('part because', 3), ('and how', 3), ('the point', 3), ('off the', 3), ('that the', 3), ('to have', 3), ('a certain', 3), ('lot of', 3), ('point of', 3), ('a few', 3), ('station has', 3), ('devoted to', 3), ('space as', 3), ('like the', 3), ('one day', 3), ('would i', 3), ('of space', 3), ('years of', 3), ('us side', 3), ('you lose', 3), ('mike hopkins', 3), ('you want', 3), ('that way', 3), ('astronauts the', 3), ('that he', 3), ('a visiting', 3), ('up there', 3), ('have any', 3), ('the same', 3), ('when youre', 3), ('the two', 2), ('a fresh', 2), ('months in', 2) ...

# %% [markdown]
# # 마르코프 모델
